# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender, als, item_knn as knn
from lenskit import topn
import lenskit as lk
import pandas as pd
# %matplotlib inline

# %%
# LOAD THE DATA IN. 
# ratings = pd.read_csv('dataSets/jester_dataset_2/jester_ratings_300.csv', skiprows=1, names=['user', 'item', 'rating'])
# ratings.head()

ratings = pd.read_csv('dataSets/jester_dataset_2/jester_ratings_formated.csv', skiprows=1, names=['user', 'item', 'rating'])
ratings.head()
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048576 entries, 0 to 1048575
# Data columns (total 3 columns):
# user      1048576 non-null int64
# item      1048576 non-null int64
# rating    1048576 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 24.0 MB

# %%
ratings = lk.util.read_df_detect('dataSets/jester_dataset_2/jester_ratings_300.csv')
ratings.head()
# Out:
#    user  item  rating
# 0     0     1     0.0
# 1     0     2     0.0
# 2     0     3     0.0
# 3     0     4     0.0
# 4     0     5     0.0

# %%
# Define the algo to use. compare to the 10 nearest nabors
algo_ii = knn.ItemItem(10)

fittable = Recommender.adapt(algo_ii)

# fit the data this may take a second depending on the side of the data file. 
fittable.fit(ratings)

users = ratings.user.unique()

# batch recommed will recmed the 
recs = batch.recommend(fittable, users, 10)
recs.head()
# Out:
#    item     score  user  rank
# 0   117  7.271889     1     1
# 1   145  6.526253     1     2
# 2   143  6.459363     1     3
# 3   129  6.014088     1     4
# 4   139  6.013389     1     5

# %%
batch.recommend(fittable, [1], 10)
# Out:
#    item     score  user  rank
# 0   117  7.271889     1     1
# 1   145  6.526253     1     2
# 2   143  6.459363     1     3
# 3   129  6.014088     1     4
# 4   139  6.013389     1     5
# 5   138  5.864237     1     6
# 6   149  5.634861     1     7
# 7   132  5.618545     1     8
# 8    56  5.600998     1     9
# 9   150  5.423547     1    10

# %%
lk.algorithms.CandidateSelector.candidates( ratings=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-5451202a9770> in <module>
#       1
# ----> 2 lk.algorithms.CandidateSelector.candidates( ratings=None)
#
# TypeError: candidates() missing 2 required positional arguments: 'self' and 'user'

# %%
algo_ii.predict_for_user(1, [117])
# Out:
# item
# 117    7.271889
# dtype: float64

# %%
# list everyting for one user
recs[recs['user']==1]
# Out:
#    item     score  user  rank
# 0   117  7.271889     1     1
# 1   145  6.526253     1     2
# 2   143  6.459363     1     3
# 3   129  6.014088     1     4
# 4   139  6.013389     1     5
# 5   138  5.864237     1     6
# 6   149  5.634861     1     7
# 7   132  5.618545     1     8
# 8    56  5.600998     1     9
# 9   150  5.423547     1    10

# %%
type(recs[recs['user']==1].score.values)
# Out:
# numpy.ndarray

# %%
# define you user, and you will get back what the system thinks the user would rank that joke. 
# it dose look like you need enfgh ranking for the bias to work. 
users = 1

ans = algo_ii.predict_for_user(users, [116], recs[recs['user']==users].score)
print(ans)
recs[recs['user']==users]
# Out:
# item
# 116    9.018601
# dtype: float64
#    item     score  user  rank
# 0   117  7.271889     1     1
# 1   145  6.526253     1     2
# 2   143  6.459363     1     3
# 3   129  6.014088     1     4
# 4   139  6.013389     1     5
# 5   138  5.864237     1     6
# 6   149  5.634861     1     7
# 7   132  5.618545     1     8
# 8    56  5.600998     1     9
# 9   150  5.423547     1    10

# %%
recs[recs['user']==4]
# Out:
#     item     score  user  rank
# 15    53  0.066313     4     1
# 16   129  0.065864     4     2
# 17    62  0.010755     4     3
# 18   105 -0.043110     4     4
# 19    50 -0.111253     4     5

# %%
recs
# Out:
#         item     score   user  rank
# 0        117  7.271889      1     1
# 1        145  6.526253      1     2
# 2        143  6.459363      1     3
# 3        129  6.014088      1     4
# 4        139  6.013389      1     5
# 5         94  6.701167      2     1
# 6        126  6.590559      2     2
# 7         78  6.507667      2     3
# 8         40  6.296014      2     4
# 9         39  6.061402      2     5
# 10        35 -2.605550      3     1
# 11       129 -2.734435      3     2
# 12        62 -2.768156      3     3
# 13        50 -2.770001      3     4
# 14        72 -2.774123      3     5
# 15        53  0.066313      4     1
# 16       129  0.065864      4     2
# 17        62  0.010755      4     3
# 18       105 -0.043110      4     4
# 19        50 -0.111253      4     5
# 20       111  5.182126      5     1
# 21       121  4.562689      5     2
# 22       138  4.550945      5     3
# 23       117  4.489741      5     4
# 24       125  4.383897      5     5
# ...

# %%
data = ['1']
 
ser = pd.Series(recs[recs['user']==1].score)
type(ser)
print(ser)
# Out:
# 0    7.271889
# 1    6.526253
# 2    6.459363
# 3    6.014088
# 4    6.013389
# Name: score, dtype: float64

# %%
algo_ii.predict_for_user(1, [114] , ser )
# Out:
# item
# 114   NaN
# dtype: float64

# %%
user_0 = pd.read_csv('dataSets/jester_dataset_2/user_0.csv', skiprows=1, names=['user', 'item', 'rating'])
user_0.head()
# Out:
#    user  item  rating
# 0     0     1       0
# 1     0     2       0
# 2     0     3       0
# 3     0     4       0
# 4     0     5       0

# %%
# user_0[user_0[iter] == 1]
user_0[user_0['item']==1]
# Out:
#    user  item  rating
# 0     0     1       0

# %%
user_0.at[ (user_0['user']==0  ), 'rating'] = 2

# %%
# this will set the users rating on a joke. 
user_0.at[ (user_0.user == 0)&(user_0.item == 2) , 'rating'] = 99

# %%
user_0[user_0['item']==1]
# Out:
#    user  item  rating
# 0     0     1       2

# %%
user_0.head()
# Out:
#    user  item  rating
# 0     0     1       2
# 1     0     2      99
# 2     0     3       2
# 3     0     4       2
# 4     0     5       2

# %%
user_0[(user_0.user == 0)&(user_0.item == 2)]
# Out:
#    user  item  rating
# 1     0     2      99

# %%
user_0.at[user_0[user_0['item']==2].rating] = 5

# %%
user_0.head(1)

# %%
user_0.at[user_0['user']==0, 'rating'] = 1

# %%
user_0.head(5)

# %%
user_0.user.iloc[2]

# %%
def eval(aname, algo, train, test):
    fittable = util.clone(algo)
    fittable = Recommender.adapt(fittable)
    fittable.fit(train)
    users = test.user.unique()
    # now we run the recommender
    recs = batch.recommend(fittable, users, 10)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
all_recs = []
test_data = []
for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
    test_data.append(test)
    all_recs.append(eval('ItemItem', algo_ii, train, test))

# %%
all_recs = pd.concat(all_recs, ignore_index=True)
print(all_recs)

# %%
# algo_ii.predict_for_user(user, items, ratings=None)
# algo_ii.predict_for_user(146, [2,4,9,11])
algo_ii.ItemItem(nnbrs=20, msize=None)

# %%
test_data = pd.concat(test_data, ignore_index=True)

# %%
rla = topn.RecListAnalysis()
rla.add_metric(topn.ndcg)
results = rla.compute(all_recs, test_data)
print(results)

# %%
results.groupby('Algorithm').ndcg.mean()

# %%
with open("Output.txt", "w") as text_file:
    print(f"Purchase Amount: {results}", file=text_file)

# %%
predict_for_user(user, items, ratings=None)
